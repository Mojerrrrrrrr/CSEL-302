# %%
import pandas as pd
import numpy as np #numerical operation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('Lesson_4_student_grades_dataset.csv')
dataset = pd.read_csv ('//content/Lesson_4_student_grades_dataset.csv')

# %%
x = dataset.drop('Grades', axis=1)
y = dataset['Grades']

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
new_data =np.array([[5,90,100,1,60]])

prediction = model.predict(new_data)

print(f"Predicted Grade: {prediction[0]}")
# Out:
# Predicted Grade: 43.435608082114285
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('Lesson_4_student_grades_dataset.csv')
df.head()
# Out:
#    Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0        4.370861              75.553988             63.085284
# 1        9.556429              86.257028             62.348940
# 2        7.587945              96.188375             95.312729
# 3        6.387926              91.966747             62.477310
# 4        2.404168              94.196834             63.597486
#
#    Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                           0              24.325977  31.494329
# 1                           0              50.132016  43.250150
# 2                           0              59.861895  30.155663
# 3                           1              11.501300  39.617522
# 4                           0              54.868293  33.175874

# %%
# @title Attendance_Percentage vs Previous_Exam_Scores

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Attendance_Percentage', y='Previous_Exam_Scores', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df = pd.read_csv('/content/Lesson_4_student_grades_dataset.csv')
print(df.head(8))
print(df.isnull().sum())
# Out:
#    Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0        4.370861              75.553988             63.085284
# 1        9.556429              86.257028             62.348940
# 2        7.587945              96.188375             95.312729
# 3        6.387926              91.966747             62.477310
# 4        2.404168              94.196834             63.597486
# 5        2.403951              89.763501             87.969913
# 6        1.522753              90.768297             72.486992
# 7        8.795585              95.475870             88.835528
#
#    Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                           0              24.325977  31.494329
# 1                           0              50.132016  43.250150
# 2                           0              59.861895  30.155663
# 3                           1              11.501300  39.617522
# 4                           0              54.868293  33.175874
# ...

# %%
slope = model.coef_[0]
intercept = model.intercept_
print("Slope:", slope)
print("Intercept:", intercept)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-61a98acff16b> in <cell line: 1>()
# ----> 1 slope = model.coef_[0]
#       2 intercept = model.intercept_
#       3 print("Slope:", slope)
#       4 print("Intercept:", intercept)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'

# %%
plt.scatter(X,Y)
plt.plot(X,model.predict(X),color='orange')
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.title('Linear Regression')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-21fac560187c> in <cell line: 1>()
# ----> 1 plt.scatter(X,Y)
#       2 plt.plot(X,model.predict(X),color='orange')
#       3 plt.xlabel('Independent Variable')
#       4 plt.ylabel('Dependent Variable')
#       5 plt.title('Linear Regression')
#
# NameError: name 'Y' is not defined
